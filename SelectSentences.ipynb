# %%
import pandas as pd

# %%
path = '/home/lucia/phd_work/shareTask/'
data = pd.read_csv(path + 'data/clpsych19_training_data/Btrain_NoNoise_SW.csv')
data
# Out:
#      Unnamed: 0 post_id  user_id   timestamp     subreddit  \
# 0            13  2bvvxg    22002  1406494593  SuicideWatch
# 1            54  20x9u6    22006  1395339794  SuicideWatch
# 2            75   tr7vb    22015  1337230954  SuicideWatch
# 3           110   ip6fx    22134  1310621370  SuicideWatch
# 4           114   j2ve3    22134  1311911038  SuicideWatch
# 5           135   xhk4e    22134  1343792229  SuicideWatch
# 6           136   xjsk1    22134  1343885091  SuicideWatch
# 7           164  1dlole    22134  1367556447  SuicideWatch
# 8           177  1hcjbb    22134  1372564540  SuicideWatch
# 9           223  2d7dzp    22354  1407730199  SuicideWatch
# 10          276  2ixwz6    22354  1413032208  SuicideWatch
# 11          313   nvtcu    22733  1325217943  SuicideWatch
# 12          315   ny0m7    22733  1325373549  SuicideWatch
# 13          323   o4qwt    22733  1325812118  SuicideWatch
# 14          365   qtuww    22733  1331603108  SuicideWatch
# ...
